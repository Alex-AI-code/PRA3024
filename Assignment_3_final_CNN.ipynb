# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-AI-code/PRA3024/blob/main/Assignment_3_final_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Some data-handling functions to download/import.

# from https://github.com/yandexdataschool/mlhep2018/blob/master/day2-Tue/seminar-03-keras-cnn/seminar_tf_keras.ipynb
"""I load some cifar"""

import numpy as np
from sklearn.model_selection import train_test_split
import os, sys
if sys.version_info[0] == 2:
    from urllib import urlretrieve
    import cPickle as pickle

else:
    from urllib.request import urlretrieve
    import pickle

def unpickle(file):
    fo = open(file, 'rb')
    if sys.version_info[0] == 2:
        dict = pickle.load(fo)
    else:
        dict = pickle.load(fo,encoding='latin1')
    
    fo.close()
    return dict




def download_cifar10(path,
                     url='https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
                     tarname='cifar-10-python.tar.gz',):
    import tarfile
    if not os.path.exists(path):
        os.mkdir(path)
    
        

    urlretrieve(url, os.path.join(path,tarname))
    tfile = tarfile.open(os.path.join(path,tarname))
    tfile.extractall(path=path)
    

def load_cifar10(data_path=".",channels_last=False,test_size=0.2,random_state=1337):
    
    test_path = os.path.join(data_path,"cifar-10-batches-py/test_batch")
    train_paths = [os.path.join(data_path,"cifar-10-batches-py/data_batch_%i"%i) for i in range(1,6)]
    
    if not os.path.exists(test_path) or not all(list(map(os.path.exists, train_paths))):
        print ("Dataset not found. Downloading...")
        download_cifar10(data_path)

    train_batches = list(map(unpickle,train_paths))
    test_batch = unpickle(test_path)

    X = np.concatenate([batch["data"] for batch in train_batches]).reshape([-1,3,32,32]).astype('float32')/255
    y = np.concatenate([batch["labels"] for batch in train_batches]).astype('int32')
    X_train,X_val,y_train,y_val = train_test_split(X,y,
                                                   test_size=test_size,
                                                   random_state=random_state)
    
    X_test = test_batch["data"].reshape([-1,3,32,32]).astype('float32')/255
    y_test = np.array(test_batch["labels"]).astype('int32')
    
    if channels_last:
        #convert from [batch,3,H,W] to [batch,H,W,3]
        #WARNING! Make this is only necessary for tensorflow-style dim order
        #If you use theano-style dimensions in keras config, skip this cell
        X_train = X_train.transpose([0,2,3,1])
        X_val   = X_val.transpose([0,2,3,1])
        X_test  = X_test.transpose([0,2,3,1])

    
    return X_train,y_train,X_val,y_val,X_test,y_test

# %%
import tensorflow as tf
#gpu_options = tf.GPUOptions(allow_growth=True, per_process_gpu_memory_fraction=0.1) # restricts GPU load for multi-user nodes

import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.4.1
# 2.4.3

# %%
# Load the data samples

x_train,y_train,x_val,y_val,x_test,y_test = load_cifar10("cifar_data",channels_last=True)

NUM_CLASSES = 10
cifar10_classes = ["airplane", "automobile", "bird", "cat", "deer", 
                   "dog", "frog", "horse", "ship", "truck"]

print("Train samples:", x_train.shape, y_train.shape)
print("Test samples:", x_test.shape, y_test.shape)
print("Val samples:", x_val.shape, y_val.shape)
# Out:
# Dataset not found. Downloading...
# Train samples: (40000, 32, 32, 3) (40000,)
# Test samples: (10000, 32, 32, 3) (10000,)
# Val samples: (10000, 32, 32, 3) (10000,)

# %%
# show some random images from train, and their labels

cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 2.5 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_train))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_train[random_index, :])
        ax.set_title(cifar10_classes[y_train[random_index]])
plt.show()

# %%
# normalize inputs
# convert class labels to one-hot encoded, should have shape (?, NUM_CLASSES)
# x_train = x_train.astype(np.float64) - 0.5

y_train = keras.utils.to_categorical(y_train, num_classes=10)

y_val = keras.utils.to_categorical(y_val, num_classes=10)

y_test = keras.utils.to_categorical(y_test, num_classes=10)

# %%
# import necessary building blocks
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
def make_model():
    """
    Define your model architecture here.
    Returns `Sequential` model.
    """


    model = Sequential()

    ### STUDENT CODE HERE ###
    ### --> Build your convolutional neural network. 
    ### First, make a CNN layer with some small kernels to learn some basic features, with Conv2D.
    ### Then, add a Pooling layer to pick up the relevant kernels.
    ### Then, Flatten it and add some fully-connected (Dense) normal NN layers,
    ###  to learn the relevant combinations of low-level kernel features.
    ### Finally, some regularisation is advised, using a Dropout layer, to avoid local minima.
    ### Make sure the output is of the same shape as the number of labels we have,
    ### And the input is the same as the figures (which now have a 3rd dimension - color!)
    ### Again, use google to find information on these classes.
    ### END STUDENT CODE ### 

    # Ensure normalized probabilities over the 10 classes


    '''
    Model Architecture: 3 convolutional layers with increasing amount of neurons
                        Batch normalization after each convalutional layer (Stabilize and accelerate the learning)
                        Increasing dropout layers (regularizing effect to adapt remaining nodes)(in general dropout work very well for this dataset)
                        I also flatten to convert data into single feature vector
    '''

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(*[32,32],3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.1, name="dropout_out1"))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2, name="dropout_out2"))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3, name="dropout_out3"))


    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(10))
    model.add(Dropout(0.4, name="dropout_out4"))
    model.add(Dense(10, activation="softmax"))


    return model

# %%
    #Implemenation of Early stopping
    callback = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=15,restore_best_weights=True)

# %%
### STUDENT CODE HERE ###
### --> change the parameters below to perform a better training



INIT_LR = 1e-3  # initial learning rate
BATCH_SIZE = 64 #define the batch size
EPOCHS = 400

#-------------------------------------------------------------------------------

K.clear_session()  # clear default graph
# don't call K.set_learning_phase() !!! (otherwise will enable dropout in train/test simultaneously)
model = make_model()  # define our model

# prepare model for fitting (loss, optimizer, etc)
model.compile(
    loss='categorical_crossentropy',  # we train 10-way classification
    optimizer=keras.optimizers.Adamax(lr=INIT_LR),  # for SGD.
    metrics=['accuracy']  # report accuracy during training
)

#added the summary of the model
model.summary()

#-------------------------------------------------------------------------------
#Data augmentation
#Flipping the image horizontaly and slightly modifying the height and width (the images are not of best quality so any other augmentation will probably perform worse)
data_augment = ImageDataGenerator(width_shift_range=0.1, height_shift_range= 0.1, horizontal_flip= True)

train = data_augment.flow(x_train,y_train,BATCH_SIZE)
#-------------------------------------------------------------------------------

#define the steps
steps = int(x_train.shape[0]/64)

# fit model
history=model.fit_generator(
    train,  # prepared the augmented data
    steps_per_epoch=steps,
    callbacks=[callback], #Here I add early stopping
    epochs=EPOCHS,
    validation_data=(x_val, y_val),
    shuffle=True,
)

# save weights to file to avoid re-training
model.save_weights("weights.h5")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_out1 (Dropout)       (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_out2 (Dropout)       (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 1, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1, 1, 128)         512
# _________________________________________________________________
# dropout_out3 (Dropout)       (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dropout_out4 (Dropout)       (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# =================================================================
# Total params: 307,224
# Trainable params: 306,072
# Non-trainable params: 1,152
# _________________________________________________________________
# Epoch 1/400
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 625/625 [==============================] - 21s 32ms/step - loss: 2.4335 - accuracy: 0.1993 - val_loss: 1.6272 - val_accuracy: 0.4255
# Epoch 2/400
# 625/625 [==============================] - 20s 31ms/step - loss: 1.8135 - accuracy: 0.3390 - val_loss: 1.3898 - val_accuracy: 0.5034
# Epoch 3/400
# 625/625 [==============================] - 19s 31ms/step - loss: 1.6122 - accuracy: 0.4195 - val_loss: 1.4709 - val_accuracy: 0.4887
# Epoch 4/400
# 625/625 [==============================] - 19s 31ms/step - loss: 1.4670 - accuracy: 0.4782 - val_loss: 1.1864 - val_accuracy: 0.5855
# Epoch 5/400
# 625/625 [==============================] - 19s 31ms/step - loss: 1.3523 - accuracy: 0.5272 - val_loss: 1.0692 - val_accuracy: 0.6230
# Epoch 6/400
# 625/625 [==============================] - 20s 32ms/step - loss: 1.2712 - accuracy: 0.5597 - val_loss: 1.0074 - val_accuracy: 0.6492
# Epoch 7/400
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1987 - accuracy: 0.5908 - val_loss: 0.9847 - val_accuracy: 0.6601
# Epoch 8/400
# 625/625 [==============================] - 20s 31ms/step - loss: 1.1472 - accuracy: 0.6094 - val_loss: 0.8430 - val_accuracy: 0.7053
# Epoch 9/400
# 625/625 [==============================] - 20s 32ms/step - loss: 1.0897 - accuracy: 0.6330 - val_loss: 1.0031 - val_accuracy: 0.6596
# Epoch 10/400
# 625/625 [==============================] - 20s 31ms/step - loss: 1.0602 - accuracy: 0.6459 - val_loss: 0.8159 - val_accuracy: 0.7159
# Epoch 11/400
# 625/625 [==============================] - 20s 31ms/step - loss: 1.0407 - accuracy: 0.6523 - val_loss: 0.8969 - val_accuracy: 0.6982
# Epoch 12/400
# 625/625 [==============================] - 19s 31ms/step - loss: 1.0070 - accuracy: 0.6655 - val_loss: 0.7669 - val_accuracy: 0.7366
# Epoch 13/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.9845 - accuracy: 0.6687 - val_loss: 0.7625 - val_accuracy: 0.7346
# Epoch 14/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.9775 - accuracy: 0.6761 - val_loss: 0.7881 - val_accuracy: 0.7368
# Epoch 15/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.9412 - accuracy: 0.6878 - val_loss: 0.7141 - val_accuracy: 0.7554
# Epoch 16/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.9087 - accuracy: 0.7013 - val_loss: 0.7094 - val_accuracy: 0.7622
# Epoch 17/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.9033 - accuracy: 0.7036 - val_loss: 0.6649 - val_accuracy: 0.7722
# Epoch 18/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.8926 - accuracy: 0.7106 - val_loss: 0.6677 - val_accuracy: 0.7691
# Epoch 19/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.8663 - accuracy: 0.7137 - val_loss: 0.6910 - val_accuracy: 0.7678
# Epoch 20/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.8554 - accuracy: 0.7205 - val_loss: 0.6170 - val_accuracy: 0.7945
# Epoch 21/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.8526 - accuracy: 0.7220 - val_loss: 0.6625 - val_accuracy: 0.7782
# Epoch 22/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.8480 - accuracy: 0.7236 - val_loss: 0.6463 - val_accuracy: 0.7826
# Epoch 23/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.8373 - accuracy: 0.7293 - val_loss: 0.6849 - val_accuracy: 0.7715
# Epoch 24/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.8246 - accuracy: 0.7348 - val_loss: 0.6182 - val_accuracy: 0.7923
# Epoch 25/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.8183 - accuracy: 0.7364 - val_loss: 0.6346 - val_accuracy: 0.7868
# Epoch 26/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7889 - accuracy: 0.7401 - val_loss: 0.6461 - val_accuracy: 0.7858
# Epoch 27/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7906 - accuracy: 0.7394 - val_loss: 0.6161 - val_accuracy: 0.7984
# Epoch 28/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.8043 - accuracy: 0.7402 - val_loss: 0.6095 - val_accuracy: 0.8003
# Epoch 29/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7830 - accuracy: 0.7438 - val_loss: 0.5724 - val_accuracy: 0.8105
# Epoch 30/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7759 - accuracy: 0.7537 - val_loss: 0.5533 - val_accuracy: 0.8187
# Epoch 31/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.7713 - accuracy: 0.7541 - val_loss: 0.6012 - val_accuracy: 0.8010
# Epoch 32/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7754 - accuracy: 0.7506 - val_loss: 0.5792 - val_accuracy: 0.8108
# Epoch 33/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7551 - accuracy: 0.7555 - val_loss: 0.6138 - val_accuracy: 0.7972
# Epoch 34/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7423 - accuracy: 0.7591 - val_loss: 0.5832 - val_accuracy: 0.8098
# Epoch 35/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7441 - accuracy: 0.7580 - val_loss: 0.5648 - val_accuracy: 0.8158
# Epoch 36/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.7510 - accuracy: 0.7577 - val_loss: 0.5745 - val_accuracy: 0.8084
# Epoch 37/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7278 - accuracy: 0.7651 - val_loss: 0.6143 - val_accuracy: 0.7960
# Epoch 38/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.7284 - accuracy: 0.7639 - val_loss: 0.5683 - val_accuracy: 0.8179
# Epoch 39/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.7126 - accuracy: 0.7687 - val_loss: 0.5383 - val_accuracy: 0.8231
# Epoch 40/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.7147 - accuracy: 0.7697 - val_loss: 0.5447 - val_accuracy: 0.8213
# Epoch 41/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.7086 - accuracy: 0.7665 - val_loss: 0.5556 - val_accuracy: 0.8160
# Epoch 42/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.7166 - accuracy: 0.7686 - val_loss: 0.5372 - val_accuracy: 0.8239
# Epoch 43/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.7010 - accuracy: 0.7768 - val_loss: 0.5994 - val_accuracy: 0.8051
# Epoch 44/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.6941 - accuracy: 0.7787 - val_loss: 0.5653 - val_accuracy: 0.8202
# Epoch 45/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.6928 - accuracy: 0.7786 - val_loss: 0.5414 - val_accuracy: 0.8236
# Epoch 46/400
# 625/625 [==============================] - 19s 31ms/step - loss: 0.6842 - accuracy: 0.7796 - val_loss: 0.5303 - val_accuracy: 0.8287
# Epoch 47/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6771 - accuracy: 0.7819 - val_loss: 0.5262 - val_accuracy: 0.8290
# Epoch 48/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6944 - accuracy: 0.7788 - val_loss: 0.6190 - val_accuracy: 0.8046
# Epoch 49/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6843 - accuracy: 0.7804 - val_loss: 0.5463 - val_accuracy: 0.8233
# Epoch 50/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.6833 - accuracy: 0.7825 - val_loss: 0.5103 - val_accuracy: 0.8365
# Epoch 51/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.6680 - accuracy: 0.7846 - val_loss: 0.5252 - val_accuracy: 0.8315
# Epoch 52/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6669 - accuracy: 0.7847 - val_loss: 0.5421 - val_accuracy: 0.8232
# Epoch 53/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6624 - accuracy: 0.7850 - val_loss: 0.5422 - val_accuracy: 0.8258
# Epoch 54/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6659 - accuracy: 0.7882 - val_loss: 0.5222 - val_accuracy: 0.8319
# Epoch 55/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6487 - accuracy: 0.7926 - val_loss: 0.5512 - val_accuracy: 0.8239
# Epoch 56/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6543 - accuracy: 0.7920 - val_loss: 0.4891 - val_accuracy: 0.8396
# Epoch 57/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6561 - accuracy: 0.7924 - val_loss: 0.5070 - val_accuracy: 0.8369
# Epoch 58/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6418 - accuracy: 0.8001 - val_loss: 0.5140 - val_accuracy: 0.8333
# Epoch 59/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6490 - accuracy: 0.7903 - val_loss: 0.5535 - val_accuracy: 0.8230
# Epoch 60/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6390 - accuracy: 0.7947 - val_loss: 0.4805 - val_accuracy: 0.8426
# Epoch 61/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6434 - accuracy: 0.7921 - val_loss: 0.5107 - val_accuracy: 0.8355
# Epoch 62/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6385 - accuracy: 0.7978 - val_loss: 0.5299 - val_accuracy: 0.8340
# Epoch 63/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6284 - accuracy: 0.8004 - val_loss: 0.5406 - val_accuracy: 0.8272
# Epoch 64/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6341 - accuracy: 0.7983 - val_loss: 0.5279 - val_accuracy: 0.8294
# Epoch 65/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6323 - accuracy: 0.7965 - val_loss: 0.4808 - val_accuracy: 0.8426
# Epoch 66/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6301 - accuracy: 0.7985 - val_loss: 0.4923 - val_accuracy: 0.8401
# Epoch 67/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6343 - accuracy: 0.7967 - val_loss: 0.5176 - val_accuracy: 0.8324
# Epoch 68/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.6198 - accuracy: 0.8002 - val_loss: 0.4812 - val_accuracy: 0.8435
# Epoch 69/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6302 - accuracy: 0.7982 - val_loss: 0.4640 - val_accuracy: 0.8463
# Epoch 70/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6162 - accuracy: 0.8006 - val_loss: 0.4870 - val_accuracy: 0.8438
# Epoch 71/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6313 - accuracy: 0.8015 - val_loss: 0.4845 - val_accuracy: 0.8430
# Epoch 72/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6094 - accuracy: 0.8064 - val_loss: 0.4860 - val_accuracy: 0.8472
# Epoch 73/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6086 - accuracy: 0.8077 - val_loss: 0.4723 - val_accuracy: 0.8481
# Epoch 74/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.6046 - accuracy: 0.8049 - val_loss: 0.4727 - val_accuracy: 0.8457
# Epoch 75/400
# 625/625 [==============================] - 20s 31ms/step - loss: 0.5992 - accuracy: 0.8106 - val_loss: 0.4810 - val_accuracy: 0.8480
# Epoch 76/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6102 - accuracy: 0.8053 - val_loss: 0.4726 - val_accuracy: 0.8454
# Epoch 77/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6013 - accuracy: 0.8126 - val_loss: 0.4883 - val_accuracy: 0.8464
# Epoch 78/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5998 - accuracy: 0.8105 - val_loss: 0.4887 - val_accuracy: 0.8488
# Epoch 79/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.6025 - accuracy: 0.8087 - val_loss: 0.5015 - val_accuracy: 0.8409
# Epoch 80/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5952 - accuracy: 0.8097 - val_loss: 0.4743 - val_accuracy: 0.8448
# Epoch 81/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5970 - accuracy: 0.8121 - val_loss: 0.4751 - val_accuracy: 0.8457
# Epoch 82/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5924 - accuracy: 0.8127 - val_loss: 0.4979 - val_accuracy: 0.8364
# Epoch 83/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5942 - accuracy: 0.8085 - val_loss: 0.5265 - val_accuracy: 0.8353
# Epoch 84/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5922 - accuracy: 0.8093 - val_loss: 0.4894 - val_accuracy: 0.8430
# Epoch 85/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5951 - accuracy: 0.8092 - val_loss: 0.4770 - val_accuracy: 0.8461
# Epoch 86/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5910 - accuracy: 0.8106 - val_loss: 0.5089 - val_accuracy: 0.8385
# Epoch 87/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5902 - accuracy: 0.8106 - val_loss: 0.4774 - val_accuracy: 0.8448
# Epoch 88/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5815 - accuracy: 0.8137 - val_loss: 0.5049 - val_accuracy: 0.8402
# Epoch 89/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5725 - accuracy: 0.8153 - val_loss: 0.5174 - val_accuracy: 0.8327
# Epoch 90/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5817 - accuracy: 0.8180 - val_loss: 0.4549 - val_accuracy: 0.8527
# Epoch 91/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5866 - accuracy: 0.8136 - val_loss: 0.4618 - val_accuracy: 0.8508
# Epoch 92/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5871 - accuracy: 0.8136 - val_loss: 0.5495 - val_accuracy: 0.8276
# Epoch 93/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5909 - accuracy: 0.8126 - val_loss: 0.4711 - val_accuracy: 0.8520
# Epoch 94/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5735 - accuracy: 0.8186 - val_loss: 0.4619 - val_accuracy: 0.8559
# Epoch 95/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5638 - accuracy: 0.8213 - val_loss: 0.4512 - val_accuracy: 0.8547
# Epoch 96/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5821 - accuracy: 0.8123 - val_loss: 0.4861 - val_accuracy: 0.8447
# Epoch 97/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5788 - accuracy: 0.8153 - val_loss: 0.5147 - val_accuracy: 0.8397
# Epoch 98/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5666 - accuracy: 0.8194 - val_loss: 0.5037 - val_accuracy: 0.8427
# Epoch 99/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5654 - accuracy: 0.8204 - val_loss: 0.4942 - val_accuracy: 0.8439
# Epoch 100/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5693 - accuracy: 0.8200 - val_loss: 0.5030 - val_accuracy: 0.8408
# Epoch 101/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5756 - accuracy: 0.8200 - val_loss: 0.4518 - val_accuracy: 0.8549
# Epoch 102/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5822 - accuracy: 0.8143 - val_loss: 0.4573 - val_accuracy: 0.8561
# Epoch 103/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5713 - accuracy: 0.8182 - val_loss: 0.4774 - val_accuracy: 0.8483
# Epoch 104/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5495 - accuracy: 0.8239 - val_loss: 0.4587 - val_accuracy: 0.8531
# Epoch 105/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5723 - accuracy: 0.8180 - val_loss: 0.4568 - val_accuracy: 0.8539
# Epoch 106/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5625 - accuracy: 0.8194 - val_loss: 0.4588 - val_accuracy: 0.8526
# Epoch 107/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5541 - accuracy: 0.8253 - val_loss: 0.4495 - val_accuracy: 0.8560
# Epoch 108/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5421 - accuracy: 0.8277 - val_loss: 0.4632 - val_accuracy: 0.8537
# Epoch 109/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5596 - accuracy: 0.8201 - val_loss: 0.4603 - val_accuracy: 0.8546
# Epoch 110/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5474 - accuracy: 0.8267 - val_loss: 0.4596 - val_accuracy: 0.8537
# Epoch 111/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5422 - accuracy: 0.8289 - val_loss: 0.4859 - val_accuracy: 0.8493
# Epoch 112/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5421 - accuracy: 0.8276 - val_loss: 0.4473 - val_accuracy: 0.8576
# Epoch 113/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5528 - accuracy: 0.8243 - val_loss: 0.4450 - val_accuracy: 0.8577
# Epoch 114/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5493 - accuracy: 0.8289 - val_loss: 0.4419 - val_accuracy: 0.8585
# Epoch 115/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5421 - accuracy: 0.8295 - val_loss: 0.4728 - val_accuracy: 0.8510
# Epoch 116/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5318 - accuracy: 0.8340 - val_loss: 0.4359 - val_accuracy: 0.8593
# Epoch 117/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5457 - accuracy: 0.8270 - val_loss: 0.4491 - val_accuracy: 0.8582
# Epoch 118/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5464 - accuracy: 0.8252 - val_loss: 0.4394 - val_accuracy: 0.8612
# Epoch 119/400
# 625/625 [==============================] - 20s 33ms/step - loss: 0.5358 - accuracy: 0.8323 - val_loss: 0.4627 - val_accuracy: 0.8554
# Epoch 120/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5338 - accuracy: 0.8304 - val_loss: 0.4413 - val_accuracy: 0.8581
# Epoch 121/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5291 - accuracy: 0.8325 - val_loss: 0.4796 - val_accuracy: 0.8498
# Epoch 122/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5317 - accuracy: 0.8292 - val_loss: 0.4603 - val_accuracy: 0.8574
# Epoch 123/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5528 - accuracy: 0.8260 - val_loss: 0.4806 - val_accuracy: 0.8518
# Epoch 124/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5351 - accuracy: 0.8294 - val_loss: 0.4812 - val_accuracy: 0.8484
# Epoch 125/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5324 - accuracy: 0.8328 - val_loss: 0.4636 - val_accuracy: 0.8562
# Epoch 126/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5284 - accuracy: 0.8316 - val_loss: 0.4935 - val_accuracy: 0.8510
# Epoch 127/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5330 - accuracy: 0.8301 - val_loss: 0.4482 - val_accuracy: 0.8600
# Epoch 128/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5196 - accuracy: 0.8392 - val_loss: 0.4660 - val_accuracy: 0.8530
# Epoch 129/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5314 - accuracy: 0.8349 - val_loss: 0.4478 - val_accuracy: 0.8574
# Epoch 130/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5215 - accuracy: 0.8332 - val_loss: 0.4667 - val_accuracy: 0.8537
# Epoch 131/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5294 - accuracy: 0.8330 - val_loss: 0.4439 - val_accuracy: 0.8621
# Epoch 132/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5228 - accuracy: 0.8334 - val_loss: 0.4424 - val_accuracy: 0.8610
# Epoch 133/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5332 - accuracy: 0.8323 - val_loss: 0.5256 - val_accuracy: 0.8344
# Epoch 134/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5236 - accuracy: 0.8331 - val_loss: 0.4581 - val_accuracy: 0.8586
# Epoch 135/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5177 - accuracy: 0.8351 - val_loss: 0.4695 - val_accuracy: 0.8589
# Epoch 136/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5269 - accuracy: 0.8323 - val_loss: 0.4589 - val_accuracy: 0.8600
# Epoch 137/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5261 - accuracy: 0.8325 - val_loss: 0.4892 - val_accuracy: 0.8510
# Epoch 138/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5248 - accuracy: 0.8353 - val_loss: 0.4490 - val_accuracy: 0.8594
# Epoch 139/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5295 - accuracy: 0.8355 - val_loss: 0.4453 - val_accuracy: 0.8614
# Epoch 140/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5115 - accuracy: 0.8351 - val_loss: 0.4482 - val_accuracy: 0.8594
# Epoch 141/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5113 - accuracy: 0.8366 - val_loss: 0.4905 - val_accuracy: 0.8493
# Epoch 142/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5139 - accuracy: 0.8367 - val_loss: 0.4570 - val_accuracy: 0.8561
# Epoch 143/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5213 - accuracy: 0.8325 - val_loss: 0.4767 - val_accuracy: 0.8550
# Epoch 144/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5050 - accuracy: 0.8395 - val_loss: 0.4519 - val_accuracy: 0.8605
# Epoch 145/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5127 - accuracy: 0.8370 - val_loss: 0.4910 - val_accuracy: 0.8524
# Epoch 146/400
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5239 - accuracy: 0.8333 - val_loss: 0.4672 - val_accuracy: 0.8568

# %%
# Plot the progression of the training accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

# %%
# Plot the progression of the training loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

# %%
# load weights from file (can call without model.fit)
model.load_weights("weights.h5")

# %%
# make test predictions
y_pred_test = model.predict_proba(x_test)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_pred_test_max_probas = np.max(y_pred_test, axis=1)
y_test_index = [list(onehot).index(1) for onehot in y_test]

# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test_index, y_pred_test_classes))
plt.xticks(np.arange(10), cifar10_classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), cifar10_classes, fontsize=12)
plt.colorbar()
plt.show()
print("Test accuracy:", accuracy_score(y_test_index, y_pred_test_classes))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# Test accuracy: 0.8561

# %%
# inspect preditions
cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 3 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_test))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_test[random_index, :])
        pred_label = cifar10_classes[y_pred_test_classes[random_index]]
        pred_proba = y_pred_test_max_probas[random_index]
        true_label = cifar10_classes[y_test_index[random_index]]
        ax.set_title("pred: {}\nscore: {:.3}\ntrue: {}".format(
               pred_label, pred_proba, true_label
        ))
plt.show()

# %% [markdown]
# # Some tips on how to improve:
#
# * The ultimate quest is to create a network that has as high __accuracy__ as you can push it.
#
# ## Potential grading:
# * starting at zero points
# * +2 for describing your iteration path in a report below.
# * +2 for building a network that gets above 20% accuracy
# * +1 for beating each of these milestones on __TEST__ dataset:
#     * 50% (5 total)
#     * 60% (6 total)
#     * 65% (7 total)
#     * 70% (8 total)
#     * 75% (9 total)
#     * 80% (10 total)
#
# ## Bonus points
# Common ways to get bonus points are:
# * Get higher score, obviously.
# * Anything special about your NN. For example \"A super-small/fast NN that gets 80%\" gets a bonus.
# * Any detailed analysis of the results. (saliency maps, whatever)
#
#
# ## Tips on what can be done:
#
#  * __Network size__
#    * More neurons,
#    * More layers, ([lasagne docs](http://lasagne.readthedocs.org))
#    * Nonlinearities in the hidden layers
#    * tanh, relu, leaky relu, etc
#    * Larger networks may take more epochs to train, so don't discard your net just because it could didn't beat the baseline in 5 epochs.
#
#  * __Convolution layers__
#    * they __are a must__ unless you have any super-ideas
#    * `network = lasagne.layers.Conv2DLayer(prev_layer,`
#      `                       num_filters = n_neurons,`
#      `                       filter_size = (filter width, filter height),`
#      `                       nonlinearity = some_nonlinearity)`
#    * Warning! Training convolutional networks can take long without GPU. That's okay.
#      * If you are CPU-only, we still recomment to try a simple convolutional architecture
#      * a perfect option is if you can set it up to run at nighttime and check it up at the morning.
#      * Make reasonable layer size estimates. A 128-neuron first convolution is likely an overkill.
#      * __To reduce computation__ time by a factor in exchange for some accuracy drop, try using __stride__ parameter. A stride=2 convolution should take roughly 1/4 of the default (stride=1) one.
#
#    * Plenty other layers and architectures
#      * http://lasagne.readthedocs.org/en/latest/modules/layers.html
#      * batch normalization, pooling, etc
#
#
#  * __Early Stopping__
#    * Training for 100 epochs regardless of anything is probably a bad idea.
#    * Some networks converge over 5 epochs, others - over 500.
#    * Way to go: stop when validation score is 10 iterations past maximum
#
#
#  * __Faster optimization__ -
#    * rmsprop, nesterov_momentum, adam, adagrad and so on.
#      * Converge faster and sometimes reach better optima
#      * It might make sense to tweak learning rate/momentum, other learning parameters, batch size and number of epochs
#    * __BatchNormalization__ (lasagne.layers.batch_norm) FTW!
#
#
#  * __Regularize__ to prevent overfitting
#    * Add some L2 weight norm to the loss function, theano will do the rest
#      * Can be done manually or via - http://lasagne.readthedocs.org/en/latest/modules/regularization.html
#    * Dropout - to prevent overfitting
#      * `lasagne.layers.DropoutLayer(prev_layer, p=probability_to_zero_out)`
#      * Don't overdo it. Check if it actually makes your network better
#
#
#  * __Data augmentation__ - getting 5x as large dataset for free is a great deal
#    * Zoom-in+slice = move
#    * Rotate+zoom(to remove black stripes)
#    * any other perturbations
#    * Add Noize (easiest: GaussianNoizeLayer)
#    * Simple way to do that (if you have PIL/Image):
#      * ```from scipy.misc import imrotate,imresize```
#      * and a few slicing
#    * Stay realistic. There's usually no point in flipping dogs upside down as that is not the way you usually see them.
